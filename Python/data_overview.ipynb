# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# Display all columns
pd.set_option('display.max_columns', None)

# %%
df = pd.read_csv(r"C:\Users\PUNEET\OneDrive\Desktop\deeedidy\github\HR_newwwwwwwwwwwwwwwwwwwwwww\HR_Analytics_Cleaned_Master.csv")

# %%
df.shape
# Out:
# (4327, 31)

# %%
df.head()
# Out:
#    Age Attrition     BusinessTravel              Department  DistanceFromHome  \
# 0   51        No      Travel_Rarely                   Sales                 6
# 1   31       Yes  Travel_Frequently  Research & Development                10
# 2   32        No  Travel_Frequently  Research & Development                17
# 3   38        No         Non-Travel  Research & Development                 2
# 4   32        No      Travel_Rarely  Research & Development                10
#
#    Education EducationField  EmployeeID  Gender  JobLevel  \
# 0          2  Life Sciences           1  Female         1
# 1          1  Life Sciences           2  Female         1
# 2          4          Other           3    Male         4
# 3          5  Life Sciences           4    Male         3
# 4          1        Medical           5    Male         1
#
#                      JobRole MaritalStatus  MonthlyIncome  NumCompaniesWorked  \
# 0  Healthcare Representative       Married         131160                 1.0
# 1         Research Scientist        Single          41890                 0.0
# 2            Sales Executive       Married         193280                 1.0
# 3            Human Resources       Married          83210                 3.0
# 4            Sales Executive        Single          23420                 4.0
#
#    PercentSalaryHike  StockOptionLevel  TotalWorkingYears  \
# 0                 11                 0                1.0
# 1                 23                 1                6.0
# 2                 15                 3                5.0
# 3                 11                 3               13.0
# 4                 12                 2                9.0
#
#    TrainingTimesLastYear  YearsAtCompany  YearsSinceLastPromotion  \
# 0                      6               1                        0
# 1                      3               5                        1
# 2                      2               5                        0
# 3                      5               8                        7
# 4                      2               6                        0
#
#    YearsWithCurrManager  EnvironmentSatisfaction  JobSatisfaction  \
# 0                     0                      3.0              4.0
# 1                     4                      3.0              2.0
# 2                     3                      2.0              2.0
# 3                     5                      4.0              4.0
# 4                     4                      4.0              1.0
#
#    WorkLifeBalance  JobInvolvement  PerformanceRating Education_Label  \
# 0              2.0               3                  3         College
# 1              4.0               2                  4   Below College
# 2              1.0               3                  3          Master
# 3              3.0               2                  3          Doctor
# 4              3.0               3                  3   Below College
#
#   JobSatisfaction_Label EnvironmentSatisfaction_Label WorkLifeBalance_Label  \
# 0             Very High                          High                  Good
# 1                Medium                          High                  Best
# 2                Medium                        Medium                   Bad
# 3             Very High                     Very High                Better
# 4                   Low                     Very High                Better
#
#   PerformanceRating_Label
# 0               Excellent
# 1             Outstanding
# 2               Excellent
# 3               Excellent
# 4               Excellent

# %%
df.sample(5)
# Out:
#       Age Attrition BusinessTravel              Department  DistanceFromHome  \
# 3379   50        No  Travel_Rarely  Research & Development                 5
# 4255   53        No  Travel_Rarely                   Sales                 1
# 2467   26        No  Travel_Rarely                   Sales                 8
# 3696   34        No  Travel_Rarely                   Sales                25
# 3262   35        No  Travel_Rarely  Research & Development                 1
#
#       Education EducationField  EmployeeID  Gender  JobLevel  \
# 3379          4  Life Sciences        3449    Male         1
# 4255          2  Life Sciences        4337    Male         1
# 2467          3      Marketing        2522  Female         1
# 3696          5      Marketing        3770  Female         1
# 3262          3  Life Sciences        3330    Male         3
#
#                         JobRole MaritalStatus  MonthlyIncome  \
# 3379            Sales Executive       Married         118780
# 4255                    Manager      Divorced          39890
# 2467  Healthcare Representative        Single          30330
# 3696         Research Scientist       Married          41940
# 3262  Healthcare Representative       Married         167920
#
#       NumCompaniesWorked  PercentSalaryHike  StockOptionLevel  \
# 3379                 2.0                 13                 1
# 4255                 1.0                 13                 0
# 2467                 1.0                 12                 0
# 3696                 0.0                 17                 2
# 3262                 3.0                 12                 1
#
#       TotalWorkingYears  TrainingTimesLastYear  YearsAtCompany  \
# 3379               29.0                      2               8
# 4255                5.0                      2               4
# 2467                5.0                      2               5
# 3696               12.0                      3              11
# 3262               16.0                      3              13
#
#       YearsSinceLastPromotion  YearsWithCurrManager  EnvironmentSatisfaction  \
# 3379                        7                     7                      2.0
# 4255                        1                     3                      4.0
# 2467                        1                     2                      3.0
# 3696                        5                     7                      2.0
# 3262                        4                     8                      4.0
#
#       JobSatisfaction  WorkLifeBalance  JobInvolvement  PerformanceRating  \
# 3379              3.0              2.0               3                  3
# 4255              1.0              3.0               3                  3
# 2467              4.0              3.0               2                  3
# 3696              3.0              3.0               3                  3
# 3262              2.0              3.0               4                  3
#
#      Education_Label JobSatisfaction_Label EnvironmentSatisfaction_Label  \
# 3379          Master                  High                        Medium
# 4255         College                   Low                     Very High
# 2467        Bachelor             Very High                          High
# 3696          Doctor                  High                        Medium
# 3262        Bachelor                Medium                     Very High
#
#      WorkLifeBalance_Label PerformanceRating_Label
# 3379                  Good               Excellent
# 4255                Better               Excellent
# 2467                Better               Excellent
# 3696                Better               Excellent
# 3262                Better               Excellent

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4327 entries, 0 to 4326
# Data columns (total 31 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Age                            4327 non-null   int64
#  1   Attrition                      4327 non-null   object
#  2   BusinessTravel                 4327 non-null   object
#  3   Department                     4327 non-null   object
#  4   DistanceFromHome               4327 non-null   int64
#  5   Education                      4327 non-null   int64
#  6   EducationField                 4327 non-null   object
#  7   EmployeeID                     4327 non-null   int64
#  8   Gender                         4327 non-null   object
#  9   JobLevel                       4327 non-null   int64
#  10  JobRole                        4327 non-null   object
#  11  MaritalStatus                  4327 non-null   object
#  12  MonthlyIncome                  4327 non-null   int64
#  13  NumCompaniesWorked             4327 non-null   float64
#  14  PercentSalaryHike              4327 non-null   int64
#  15  StockOptionLevel               4327 non-null   int64
#  16  TotalWorkingYears              4327 non-null   float64
#  17  TrainingTimesLastYear          4327 non-null   int64
#  18  YearsAtCompany                 4327 non-null   int64
#  19  YearsSinceLastPromotion        4327 non-null   int64
#  20  YearsWithCurrManager           4327 non-null   int64
#  21  EnvironmentSatisfaction        4327 non-null   float64
#  22  JobSatisfaction                4327 non-null   float64
#  23  WorkLifeBalance                4327 non-null   float64
#  24  JobInvolvement                 4327 non-null   int64
#  25  PerformanceRating              4327 non-null   int64
#  26  Education_Label                4327 non-null   object
#  27  JobSatisfaction_Label          4327 non-null   object
#  28  EnvironmentSatisfaction_Label  4327 non-null   object
#  29  WorkLifeBalance_Label          4327 non-null   object
#  30  PerformanceRating_Label        4327 non-null   object
# dtypes: float64(5), int64(14), object(12)
# memory usage: 1.0+ MB

# %%
df.describe()
# Out:
#                Age  DistanceFromHome    Education   EmployeeID     JobLevel  \
# count  4327.000000       4327.000000  4327.000000  4327.000000  4327.000000
# mean     36.916570          9.186966     2.913797  2208.812803     2.067021
# std       9.143345          8.092618     1.024080  1273.370663     1.107342
# min      18.000000          1.000000     1.000000     1.000000     1.000000
# 25%      30.000000          2.000000     2.000000  1105.500000     1.000000
# 50%      36.000000          7.000000     3.000000  2212.000000     2.000000
# 75%      43.000000         14.000000     4.000000  3312.500000     3.000000
# max      60.000000         29.000000     5.000000  4409.000000     5.000000
#
#        MonthlyIncome  NumCompaniesWorked  PercentSalaryHike  StockOptionLevel  \
# count    4327.000000         4327.000000        4327.000000       4327.000000
# mean    65029.244280            2.689161          15.210307          0.794777
# std     46976.222828            2.491730           3.658903          0.853017
# min     10090.000000            0.000000          11.000000          0.000000
# 25%     29260.000000            1.000000          12.000000          0.000000
# 50%     49360.000000            2.000000          14.000000          1.000000
# 75%     83805.000000            4.000000          18.000000          1.000000
# max    199990.000000            9.000000          25.000000          3.000000
#
#        TotalWorkingYears  TrainingTimesLastYear  YearsAtCompany  \
# count        4327.000000            4327.000000     4327.000000
# mean           11.272244               2.796626        7.020337
# std             7.779457               1.288936        6.140673
# min             0.000000               0.000000        0.000000
# 25%             6.000000               2.000000        3.000000
# 50%            10.000000               3.000000        5.000000
# 75%            15.000000               3.000000        9.000000
# max            40.000000               6.000000       40.000000
#
#        YearsSinceLastPromotion  YearsWithCurrManager  EnvironmentSatisfaction  \
# count              4327.000000           4327.000000              4327.000000
# mean                  2.185810              4.128264                 2.724520
# std                   3.227776              3.563110                 1.092955
# min                   0.000000              0.000000                 1.000000
# 25%                   0.000000              2.000000                 2.000000
# 50%                   1.000000              3.000000                 3.000000
# 75%                   3.000000              7.000000                 4.000000
# max                  15.000000             17.000000                 4.000000
#
#        JobSatisfaction  WorkLifeBalance  JobInvolvement  PerformanceRating
# count      4327.000000      4327.000000     4327.000000        4327.000000
# mean          2.724983         2.761498        2.727987           3.153686
# std           1.101498         0.706921        0.711318           0.360689
# min           1.000000         1.000000        1.000000           3.000000
# 25%           2.000000         2.000000        2.000000           3.000000
# 50%           3.000000         3.000000        3.000000           3.000000
# 75%           4.000000         3.000000        3.000000           3.000000
# max           4.000000         4.000000        4.000000           4.000000

# %%
df.describe(include='object')
# Out:
#        Attrition BusinessTravel              Department EducationField Gender  \
# count       4327           4327                    4327           4327   4327
# unique         2              3                       3              6      2
# top           No  Travel_Rarely  Research & Development  Life Sciences   Male
# freq        3626           3070                    2824           1778   2590
#
#                 JobRole MaritalStatus Education_Label JobSatisfaction_Label  \
# count              4327          4327            4327                  4327
# unique                9             3               5                     4
# top     Sales Executive       Married        Bachelor             Very High
# freq                959          1981            1684                  1342
#
#        EnvironmentSatisfaction_Label WorkLifeBalance_Label  \
# count                           4327                  4327
# unique                             4                     4
# top                             High                Better
# freq                            1330                  2630
#
#        PerformanceRating_Label
# count                     4327
# unique                       2
# top                  Excellent
# freq                      3662

# %%
df.isnull().sum()
# Out:
# Age                              0
# Attrition                        0
# BusinessTravel                   0
# Department                       0
# DistanceFromHome                 0
# Education                        0
# EducationField                   0
# EmployeeID                       0
# Gender                           0
# JobLevel                         0
# JobRole                          0
# MaritalStatus                    0
# MonthlyIncome                    0
# NumCompaniesWorked               0
# PercentSalaryHike                0
# StockOptionLevel                 0
# TotalWorkingYears                0
# TrainingTimesLastYear            0
# YearsAtCompany                   0
# YearsSinceLastPromotion          0
# YearsWithCurrManager             0
# EnvironmentSatisfaction          0
# JobSatisfaction                  0
# WorkLifeBalance                  0
# JobInvolvement                   0
# PerformanceRating                0
# Education_Label                  0
# JobSatisfaction_Label            0
# EnvironmentSatisfaction_Label    0
# WorkLifeBalance_Label            0
# PerformanceRating_Label          0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
(df.isnull().sum()/len(df))*100
# Out:
# Age                              0.0
# Attrition                        0.0
# BusinessTravel                   0.0
# Department                       0.0
# DistanceFromHome                 0.0
# Education                        0.0
# EducationField                   0.0
# EmployeeID                       0.0
# Gender                           0.0
# JobLevel                         0.0
# JobRole                          0.0
# MaritalStatus                    0.0
# MonthlyIncome                    0.0
# NumCompaniesWorked               0.0
# PercentSalaryHike                0.0
# StockOptionLevel                 0.0
# TotalWorkingYears                0.0
# TrainingTimesLastYear            0.0
# YearsAtCompany                   0.0
# YearsSinceLastPromotion          0.0
# YearsWithCurrManager             0.0
# EnvironmentSatisfaction          0.0
# JobSatisfaction                  0.0
# WorkLifeBalance                  0.0
# JobInvolvement                   0.0
# PerformanceRating                0.0
# Education_Label                  0.0
# JobSatisfaction_Label            0.0
# EnvironmentSatisfaction_Label    0.0
# WorkLifeBalance_Label            0.0
# PerformanceRating_Label          0.0
# dtype: float64

# %%
float_cols = [
    'NumCompaniesWorked',
    'TotalWorkingYears',
    'EnvironmentSatisfaction',
    'JobSatisfaction',
    'WorkLifeBalance'
]

df[float_cols] = df[float_cols].astype(int)

# %%
(df['YearsSinceLastPromotion'] > df['YearsAtCompany']).sum()
# Out:
# np.int64(0)

# %%
(df['YearsWithCurrManager'] > df['YearsAtCompany']).sum()
# Out:
# np.int64(0)

# %%
df['EmployeeID'].nunique(), len(df)
# Out:
# (4327, 4327)

# %%
df['Department'].unique()
# Out:
# array(['Sales', 'Research & Development', 'Human Resources'], dtype=object)

# %%
df['JobRole'].unique()
# Out:
# array(['Healthcare Representative', 'Research Scientist',
#        'Sales Executive', 'Human Resources', 'Research Director',
#        'Laboratory Technician', 'Manufacturing Director',
#        'Sales Representative', 'Manager'], dtype=object)

# %%
df['Gender'].unique()
# Out:
# array(['Female', 'Male'], dtype=object)

# %%
df['MaritalStatus'].unique()
# Out:
# array(['Married', 'Single', 'Divorced'], dtype=object)

# %%
df['Department'].value_counts()
# Out:
# Department
# Research & Development    2824
# Sales                     1315
# Human Resources            188
# Name: count, dtype: int64

# %%
df['JobRole'].value_counts()
# Out:
# JobRole
# Sales Executive              959
# Research Scientist           863
# Laboratory Technician        760
# Manufacturing Director       428
# Healthcare Representative    381
# Manager                      300
# Sales Representative         244
# Research Director            238
# Human Resources              154
# Name: count, dtype: int64
